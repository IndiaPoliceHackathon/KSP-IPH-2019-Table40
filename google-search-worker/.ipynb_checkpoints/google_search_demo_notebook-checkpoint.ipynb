# %%
import calendar
import os
import platform
import sys
import urllib.request
import time

from selenium import webdriver
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

facebook_domain = "https://facebook.com/"

def safe_find_element_by_id(driver, elem_id):
    try:
        return driver.find_element_by_id(elem_id)
    except NoSuchElementException:
        return None

def login(email, password, driver):
    """ Logging into our own profile """


    try:
        driver.get(facebook_domain)

        # filling the form
        driver.find_element_by_name('email').send_keys(email)
        driver.find_element_by_name('pass').send_keys(password)

        # clicking on login button
        driver.find_element_by_id('loginbutton').click()

        # if your account uses multi factor authentication
        mfa_code_input = safe_find_element_by_id(driver, 'approvals_code')

        if mfa_code_input is None:
            return

        mfa_code_input.send_keys(input("Enter MFA code: "))
        driver.find_element_by_id('checkpointSubmitButton').click()

        # there are so many screens asking you to verify things. Just skip them all
        while safe_find_element_by_id(driver, 'checkpointSubmitButton') is not None:
            dont_save_browser_radio = safe_find_element_by_id(driver, 'u_0_3')
            if dont_save_browser_radio is not None:
                dont_save_browser_radio.click()

            driver.find_element_by_id('checkpointSubmitButton').click()

    except Exception:
        print("There's some error in log in.")
        print(sys.exc_info()[0])
        
def setup_driver():
    global driver

    options = Options()
    options.add_argument("--disable-notifications")
    options.add_argument("--disable-infobars")
    options.add_argument("--mute-audio")

    try:
        platform_ = platform.system().lower()
        if platform_ in ['linux', 'darwin']:
            driver = webdriver.Chrome(
                executable_path="./chromedriver", options=options)
        else:
            driver = webdriver.Chrome(
                executable_path="./chromedriver.exe", options=options)
    except Exception:
        print("Kindly replace the Chrome Web Driver with the latest one from "
                "http://chromedriver.chromium.org/downloads "
                "and also make sure you have the latest Chrome Browser version."
                "\nYour OS: {}".format(platform_)
                )
        exit()
    
    driver.maximize_window()
    

setup_driver()
login("email", "password", driver)

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 

query = "Enter your query here"
googled_urls = []
for j in search(query, num=10, stop=30, pause=2): 
    googled_urls.append(j)

# %%
for p in googled_urls:
    print(p)
# Out:
# https://www.facebook.com/prashanth.soordelu
# https://hi-in.facebook.com/public?query=Prashanth+Sakleshpur&type=users&nomc=0
# https://www.facebook.com/pages/Panchalingeshwara-Temple-Panja/1789952471328025
# https://www.facebook.com/pages/category/Community/Sisodia-Warriors-300969163408097/
# https://www.facebook.com/nithinkrishna.k
# https://www.facebook.com/1423546281197178/posts/%E0%B2%AE%E0%B2%B3%E0%B3%86%E0%B2%AF%E0%B2%BF%E0%B2%82%E0%B2%A6-%E0%B2%B8%E0%B3%83%E0%B2%B7%E0%B3%8D%E0%B2%9F%E0%B2%BF%E0%B2%AF%E0%B2%BE%E0%B2%A6-%E0%B2%B0%E0%B2%B8%E0%B3%8D%E0%B2%A4%E0%B3%86-%E0%B2%B9%E0%B3%8A%E0%B2%82%E0%B2%A1%E0%B2%97%E0%B2%B3%E0%B2%BF%E0%B2%97%E0%B3%86-%E0%B2%B8%E0%B3%81%E0%B2%A6%E0%B2%B0%E0%B3%8D%E0%B2%B6%E0%B2%A8%E0%B2%A6%E0%B2%BF%E0%B2%82%E0%B2%A6-%E0%B2%85%E0%B2%82%E0%B2%A4%E0%B2%BF%E0%B2%AE-%E0%B2%B8%E0%B3%8D%E0%B2%AA%E0%B2%B0%E0%B3%8D%E0%B2%B7%E0%B2%B8%E0%B3%8D%E0%B2%B5%E0%B2%B0%E0%B3%8D%E0%B2%97-%E0%B2%B8%E0%B3%87%E0%B2%A4%E0%B3%81%E0%B2%B5%E0%B3%86%E0%B2%AF%E0%B2%BF%E0%B2%82%E0%B2%A6-%E0%B2%AA%E0%B2%BE%E0%B2%A3%E0%B2%BE/1976619922556475/
# https://www.facebook.com/pages/Bilikal-Rangaswamy-Betta/617412115008171
# https://en-gb.facebook.com/mahesh.miniyar
# https://hi-in.facebook.com/nithinkrishna.k
# https://www.facebook.com/Vaninagarkasaragodkerala-545638882150599/posts/
# https://business.facebook.com/pages/Panchalingeshwara-Temple-Panja/1789952471328025
# https://es-la.facebook.com/BJP4Kasaragod/posts
# https://www.facebook.com/directory/people/T-27857571-27868516
# https://pa-in.facebook.com/mcesays/posts
# https://www.pictame.com/user/kishore8862/followings/3582317967
# https://twitter.com/astitvam/status/767905933812834304
# https://www.twigur.com/hashtag/Tippujayanti
# https://www.facebook.com/pages/category/Organization/I-Love-MY-maaMUMMYmom-352605658128909/
# https://ja-jp.facebook.com/pages/category/City/Vaninagarkasaragodkerala-545638882150599/posts/
# https://www.youtube.com/playlist?list=PLeiNBZsOC4aS0ZepHtwFjnuCO1-4V6Z37
# http://11038nhsperdala.blogspot.com/2014/11/
# http://hotsta.org/shivart93/followers
# https://en.unionpedia.org/i/Thiruvananthapuram
# https://en.unionpedia.org/i/Kozhikode
# http://pakvim.net/watch/RzZ6UUogKVY
# https://wikivisually.com/wiki/User:Lfstevens/May_2016_copy-edits
# https://artorrent.info/P61iYL7hvV-8mVsLcE4utCg
# http://videobring.com/tag/kateel-durga-parameshwari-temple
# https://intorrent.info/watch/ZZeddqfJm5FwsHM.html
# https://www.vi-tu.top/?q=hanumagiri

# %%
import time
import urllib.request
count = 0
req_urls = []
for i in googled_urls:
    if(((i.count('/') <= 3) and (i.count('facebook.com') == 1) and (i.count('?') < 1)) or ((i.count('/') ==4) and (i.count('facebook.com') == 1) and (i[-1]=='/'))):
        facebook_username = i.split("/")[-1]
        driver.get("https://facebook.com/"+facebook_username)
        
        fileName = str(facebook_username) + ".jpeg"
        driver.find_element_by_id('u_0_v').click()
        time.sleep(4)
        
        try:
            element = driver.find_element_by_class_name("spotlight")
            img_url = element.get_attribute('src')
            print(img_url)
        
            if img_url.find('.gif') == -1:
                try:
                    print('----------------')
                    req_urls.append(i)
                    urllib.request.urlretrieve(img_url, fileName)
                except Exception as e:
                    print(str(e))
        
        except:
            print("-Not found-")
# Out:
# https://scontent.fhyd12-1.fna.fbcdn.net/v/t31.0-8/p960x960/14242285_1763381790595085_114273927997936842_o.jpg?_nc_cat=109&_nc_oc=AQnywOPNIy856Lju0apBjOflQcQhOAQ51I-yat5TRWra67o5OQDeLWVJmg0E-NeqcqU&_nc_ht=scontent.fhyd12-1.fna&oh=b7aae4be29ba7a19d9c6eb8706c3aa48&oe=5E419718
# lol
# https://scontent.fhyd12-1.fna.fbcdn.net/v/t1.0-9/s960x960/75462521_2996156657080511_5943026318550499328_o.jpg?_nc_cat=101&_nc_oc=AQkzN3hUbO2f9gab1BtuQG646YJEMujYIg-tCJeXkfMwUShf_A1HYSZecc1am8N8fc0&_nc_ht=scontent.fhyd12-1.fna&oh=1c57fd3daa794ef5bd8008a36becc6df&oe=5E497830
# lol
# Not found--------------------
# https://scontent.fhyd12-1.fna.fbcdn.net/v/t1.0-9/s960x960/75462521_2996156657080511_5943026318550499328_o.jpg?_nc_cat=101&_nc_oc=AQkzN3hUbO2f9gab1BtuQG646YJEMujYIg-tCJeXkfMwUShf_A1HYSZecc1am8N8fc0&_nc_ht=scontent.fhyd12-1.fna&oh=1c57fd3daa794ef5bd8008a36becc6df&oe=5E497830
# lol

# %%
print(req_urls)
# Out:
# ['https://www.facebook.com/prashanth.soordelu', 'https://www.facebook.com/nithinkrishna.k', 'https://hi-in.facebook.com/nithinkrishna.k']

# %%
import boto3
import time
# Setting the credentials
ACCESS_KEY = 'access key'
SECRET_KEY = 'secret '

s3 = boto3.client('s3',
                    region_name="us-east-1",
                    aws_access_key_id=ACCESS_KEY,
                    aws_secret_access_key=SECRET_KEY)

for i in req_urls:
    if(i.split("/")[-1] == ''):
        file_name = i.split("/")[-2]+'.jpeg'
    else:
        file_name = i.split("/")[-1]+'.jpeg'
        
    bucket = 'demo-hackathon-bucket-2'
    # file_name = 'location-of-your-file'
    key_name = file_name
    s3.upload_file(file_name, bucket, key_name,ExtraArgs={'ACL': 'public-read-write'})

# %%
from IPython.display import Image
for i in req_urls:
    if(i.split("/")[-1] == ''):
        file_name = i.split("/")[-2]+'.jpeg'
    else:
        file_name = i.split("/")[-1]+'.jpeg'
    client = boto3.client(
        'rekognition'
    )
    print(file_name)
    response = client.compare_faces(
        SimilarityThreshold=50,
        SourceImage={
            'S3Object': {
                'Bucket': 'demo-hackathon-bucket',
                'Name': 'prash.jpeg'
            }
        },
        TargetImage={
            'S3Object': {
                'Bucket': 'demo-hackathon-bucket-2',
                'Name': file_name
            }
        }
    )
    if(len(response['FaceMatches'])>0):
        if((response['FaceMatches'][0]['Similarity'])>90):
            print(response['FaceMatches'][0]['Similarity'])
            required_username = file_name[:-5]
print('Required username',required_username)
Image(filename=required_username +'.jpg')
# Out:
# prashanth.soordelu.jpeg
# 99.32794189453125
# nithinkrishna.k.jpeg
# nithinkrishna.k.jpeg
# Required username prashanth.soordelu
